# %%
# !pip install ultralytics onnx onnxruntime onnxslim

# %%
pip install opencv-python==4.8.1.78
# Out:
# ...
#   Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO("./runs/detect/train10/weights/best.pt")  # your trained model
model.export(format="onnx", opset=12)
# Out:
# Ultralytics 8.3.158  Python-3.9.23 torch-2.5.1+cu121 CPU (AMD Ryzen 9 5900 12-Core Processor)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from 'runs\detect\train10\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (21.5 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 12...
# ONNX: slimming with onnxslim 0.1.57...
# ONNX: export success  1.4s, saved as 'runs\detect\train10\weights\best.onnx' (42.7 MB)
#
# Export complete (1.8s)
# Results saved to C:\Users\vidha\Documents\VisAssistGlasses\Depth_Model\runs\detect\train10\weights
# Predict:         yolo predict task=detect model=runs\detect\train10\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train10\weights\best.onnx imgsz=640 data=./Indoor--1/data.yaml
# Visualize:       https://netron.app
# 'runs\\detect\\train10\\weights\\best.onnx'
